# %% [markdown]
# # Area Plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 한글 처리
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
df = pd.read_excel('./data/시도별 전출입 인구수.xlsx', header=0).fillna(0)
df.drop(0, axis=0, inplace=True)
df_cap_movein = df.iloc[[1, 9]]
df_cap_movein.drop(['전출지별'], axis=1, inplace=True)
df_cap_movein.index = df_cap_movein['전입지별']
df_cap_movein.drop(['전입지별'], axis=1, inplace=True)
df_cap_movein.head()
# Out:
# C:\Users\gik_k\AppData\Local\Temp\ipykernel_9840\3321360757.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cap_movein.drop(['전출지별'], axis=1, inplace=True)
# C:\Users\gik_k\AppData\Local\Temp\ipykernel_9840\3321360757.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cap_movein.drop(['전입지별'], axis=1, inplace=True)
#           1970     1971     1972     1973     1974     1975     1976     1977  \
# 전입지별
# 서울특별시  1742813  1671705  1349333  1831858  2050392  3396662  2756510  2893403
# 경기도     452060   533375   418045   542224   579194  1006818   770036   880019
#
#           1978     1979  ...     2008     2009     2010     2011     2012  \
# 전입지별                     ...
# 서울특별시  3307439  2589667  ...  2025358  1873188  1733015  1721748  1555281
# 경기도     985879   984187  ...  2195585  2175681  2168820  2062422  1944962
#
#           2013     2014     2015     2016     2017
# 전입지별
# 서울특별시  1520090  1573594  1589431  1515602  1472937
# 경기도    1895434  1891775  1993080  1958593  1888324
#
# [2 rows x 48 columns]

# %%
df_cap_movein.loc['수도권'] = list(df_cap_movein.sum())
# Out:
# C:\Users\gik_k\AppData\Local\Temp\ipykernel_9840\3765357216.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cap_movein.loc['수도권'] = list(df_cap_movein.sum())

# %%
df_cap_movein = df_cap_movein.transpose()

# %%
df_cap_movein.plot(kind='area')
# Out:
# <Axes: >

# %%
df = pd.read_excel('./data/시도별 전출입 인구수.xlsx', header=0).fillna(0)
df.drop(0, axis=0, inplace=True)
df_cap_movein = df.iloc[[1, 9]]
df_cap_movein.drop(['전출지별'], axis=1, inplace=True)
df_cap_movein.index = df_cap_movein['전입지별']
df_cap_movein.drop(['전입지별'], axis=1, inplace=True)
df_cap_movein.loc['수도권'] = list(df_cap_movein.sum())
df_cap_movein = df_cap_movein.transpose()
df_cap_movein.head(10)
# Out:
# C:\Users\gik_k\AppData\Local\Temp\ipykernel_9840\362717370.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cap_movein.drop(['전출지별'], axis=1, inplace=True)
# C:\Users\gik_k\AppData\Local\Temp\ipykernel_9840\362717370.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cap_movein.drop(['전입지별'], axis=1, inplace=True)
# C:\Users\gik_k\AppData\Local\Temp\ipykernel_9840\362717370.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cap_movein.loc['수도권'] = list(df_cap_movein.sum())
# 전입지별    서울특별시      경기도      수도권
# 1970  1742813   452060  2194873
# 1971  1671705   533375  2205080
# 1972  1349333   418045  1767378
# 1973  1831858   542224  2374082
# 1974  2050392   579194  2629586
# 1975  3396662  1006818  4403480
# 1976  2756510   770036  3526546
# 1977  2893403   880019  3773422
# 1978  3307439   985879  4293318
# 1979  2589667   984187  3573854

# %%
plt.style.use('ggplot')

df_cap_movein.plot(kind='area', figsize=(14, 5), alpha=0.2, stacked=False)

plt.title('수도권 인구유입 현황')
plt.xlabel('연도')
plt.ylabel('유입인구')

plt.legend(labels=['서울특별시','경기도','합계'], loc='upper left')
plt.show()

# %%
plt.style.use('ggplot')

df_cap_movein.plot(kind='area', figsize=(14, 5), alpha=0.2, stacked=True)

plt.title('수도권 인구유입 현황')
plt.xlabel('연도')
plt.ylabel('유입인구')

plt.legend(loc='upper left')
arrYticks, txtYticks = plt.yticks()
plt.yticks(arrYticks, ['{:,.0f}'.format(x) for x in arrYticks])

plt.show()
