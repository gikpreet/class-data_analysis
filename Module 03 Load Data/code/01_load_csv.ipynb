# %% [markdown]
# # CSV 데이터 로드

# %%
import pandas as pd

# %% [markdown]
# Data Source: https://jumin.mois.go.kr/ageStatMonth.do#none

# %% [markdown]
# ## Load

# %%
df_pop = pd.read_csv('./data/202410_202410_연령별인구현황_월간.csv', encoding='EUC-KR')
df_pop
# Out:
#                      행정구역 2024년10월_계_총인구수 2024년10월_계_연령구간인구수 2024년10월_계_0~9세  \
# 0        전국  (0000000000)      51,238,450         51,238,450       3,165,029
# 1     서울특별시  (1100000000)       9,343,304          9,343,304         487,458
# 2     부산광역시  (2600000000)       3,271,062          3,271,062         183,384
# 3     대구광역시  (2700000000)       2,364,892          2,364,892         143,252
# 4     인천광역시  (2800000000)       3,017,928          3,017,928         196,120
# 5     광주광역시  (2900000000)       1,410,548          1,410,548          93,779
# 6     대전광역시  (3000000000)       1,440,094          1,440,094          92,255
# 7     울산광역시  (3100000000)       1,098,540          1,098,540          73,933
# 8   세종특별자치시  (3600000000)         389,978            389,978          41,643
# 9       경기도  (4100000000)      13,686,731         13,686,731         946,337
# 10  강원특별자치도  (5100000000)       1,519,545          1,519,545          86,475
# ...

# %%
# 행정구역 컬럼을 인덱스로 만들기 위해 문자열 조작
new_index = df_pop.행정구역.str.split('(', expand=True)[0].str.strip()
new_index
# Out:
# 0          전국
# 1       서울특별시
# 2       부산광역시
# 3       대구광역시
# 4       인천광역시
# 5       광주광역시
# 6       대전광역시
# 7       울산광역시
# 8     세종특별자치시
# 9         경기도
# 10    강원특별자치도
# 11       충청북도
# 12       충청남도
# 13    전북특별자치도
# 14       전라남도
# 15       경상북도
# 16       경상남도
# 17    제주특별자치도
# Name: 0, dtype: object

# %%
# 행정구역 컬럼을 삭제하고 인덱스 지정
df_pop.drop('행정구역', axis=1, inplace=True)
df_pop.index = new_index
df_pop
# Out:
#         2024년10월_계_총인구수 2024년10월_계_연령구간인구수 2024년10월_계_0~9세 2024년10월_계_10~19세  \
# 0
# 전국           51,238,450         51,238,450       3,165,029         4,625,395
# 서울특별시         9,343,304          9,343,304         487,458           723,446
# 부산광역시         3,271,062          3,271,062         183,384           262,936
# 대구광역시         2,364,892          2,364,892         143,252           212,540
# 인천광역시         3,017,928          3,017,928         196,120           272,380
# 광주광역시         1,410,548          1,410,548          93,779           145,773
# 대전광역시         1,440,094          1,440,094          92,255           135,890
# 울산광역시         1,098,540          1,098,540          73,933           109,213
# 세종특별자치시         389,978            389,978          41,643            52,212
# 경기도          13,686,731         13,686,731         946,337         1,320,679
# 강원특별자치도       1,519,545          1,519,545          86,475           126,958
# ...

# %%
df_pop.columns
# Out:
# Index(['2024년10월_계_총인구수', '2024년10월_계_연령구간인구수', '2024년10월_계_0~9세',
#        '2024년10월_계_10~19세', '2024년10월_계_20~29세', '2024년10월_계_30~39세',
#        '2024년10월_계_40~49세', '2024년10월_계_50~59세', '2024년10월_계_60~69세',
#        '2024년10월_계_70~79세', '2024년10월_계_80~89세', '2024년10월_계_90~99세',
#        '2024년10월_계_100세 이상', '2024년10월_남_총인구수', '2024년10월_남_연령구간인구수',
#        '2024년10월_남_0~9세', '2024년10월_남_10~19세', '2024년10월_남_20~29세',
#        '2024년10월_남_30~39세', '2024년10월_남_40~49세', '2024년10월_남_50~59세',
#        '2024년10월_남_60~69세', '2024년10월_남_70~79세', '2024년10월_남_80~89세',
#        '2024년10월_남_90~99세', '2024년10월_남_100세 이상', '2024년10월_여_총인구수',
#        '2024년10월_여_연령구간인구수', '2024년10월_여_0~9세', '2024년10월_여_10~19세',
#        '2024년10월_여_20~29세', '2024년10월_여_30~39세', '2024년10월_여_40~49세',
#        '2024년10월_여_50~59세', '2024년10월_여_60~69세', '2024년10월_여_70~79세',
#        '2024년10월_여_80~89세', '2024년10월_여_90~99세', '2024년10월_여_100세 이상'],
#       dtype='object')

# %%
df_pop_total = df_pop[['2024년10월_계_총인구수', '2024년10월_계_연령구간인구수', '2024년10월_계_0~9세',
       '2024년10월_계_10~19세', '2024년10월_계_20~29세', '2024년10월_계_30~39세',
       '2024년10월_계_40~49세', '2024년10월_계_50~59세', '2024년10월_계_60~69세',
       '2024년10월_계_70~79세', '2024년10월_계_80~89세', '2024년10월_계_90~99세',
       '2024년10월_계_100세 이상']]
df_pop_total
# Out:
#         2024년10월_계_총인구수 2024년10월_계_연령구간인구수 2024년10월_계_0~9세 2024년10월_계_10~19세  \
# 0
# 전국           51,238,450         51,238,450       3,165,029         4,625,395
# 서울특별시         9,343,304          9,343,304         487,458           723,446
# 부산광역시         3,271,062          3,271,062         183,384           262,936
# 대구광역시         2,364,892          2,364,892         143,252           212,540
# 인천광역시         3,017,928          3,017,928         196,120           272,380
# 광주광역시         1,410,548          1,410,548          93,779           145,773
# 대전광역시         1,440,094          1,440,094          92,255           135,890
# 울산광역시         1,098,540          1,098,540          73,933           109,213
# 세종특별자치시         389,978            389,978          41,643            52,212
# 경기도          13,686,731         13,686,731         946,337         1,320,679
# 강원특별자치도       1,519,545          1,519,545          86,475           126,958
# ...

# %%
df_pop_total.drop('2024년10월_계_연령구간인구수', axis=1, inplace=True)
df_pop_total
# Out:
# C:\Users\gik_k\AppData\Local\Temp\ipykernel_12368\1964807311.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pop_total.drop('2024년10월_계_연령구간인구수', axis=1, inplace=True)
#         2024년10월_계_총인구수 2024년10월_계_0~9세 2024년10월_계_10~19세 2024년10월_계_20~29세  \
# 0
# 전국           51,238,450       3,165,029         4,625,395         5,998,612
# 서울특별시         9,343,304         487,458           723,446         1,318,398
# 부산광역시         3,271,062         183,384           262,936           361,691
# 대구광역시         2,364,892         143,252           212,540           270,301
# 인천광역시         3,017,928         196,120           272,380           353,794
# 광주광역시         1,410,548          93,779           145,773           183,555
# ...

# %%
current_cols = [x.split('_')[2] for x in list(df_pop_total.columns)]
df_pop_total.columns = current_cols
df_pop_total
# Out:
#                총인구수       0~9세     10~19세     20~29세     30~39세     40~49세  \
# 0
# 전국       51,238,450  3,165,029  4,625,395  5,998,612  6,612,634  7,757,529
# 서울특별시     9,343,304    487,458    723,446  1,318,398  1,439,369  1,389,768
# 부산광역시     3,271,062    183,384    262,936    361,691    389,456    473,403
# 대구광역시     2,364,892    143,252    212,540    270,301    282,272    346,404
# 인천광역시     3,017,928    196,120    272,380    353,794    420,642    476,741
# 광주광역시     1,410,548     93,779    145,773    183,555    173,765    221,038
# 대전광역시     1,440,094     92,255    135,890    194,905    190,213    214,434
# 울산광역시     1,098,540     73,933    109,213    117,870    136,434    174,044
# 세종특별자치시     389,978     41,643     52,212     37,131     58,906     77,263
# 경기도      13,686,731    946,337  1,320,679  1,637,135  1,900,885  2,222,316
# 강원특별자치도   1,519,545     86,475    126,958    157,315    158,402    201,983
# ...

# %%
df_pop_total.index.name = '자치단체명'
df_pop_total
# Out:
#                총인구수       0~9세     10~19세     20~29세     30~39세     40~49세  \
# 자치단체명
# 전국       51,238,450  3,165,029  4,625,395  5,998,612  6,612,634  7,757,529
# 서울특별시     9,343,304    487,458    723,446  1,318,398  1,439,369  1,389,768
# 부산광역시     3,271,062    183,384    262,936    361,691    389,456    473,403
# 대구광역시     2,364,892    143,252    212,540    270,301    282,272    346,404
# 인천광역시     3,017,928    196,120    272,380    353,794    420,642    476,741
# 광주광역시     1,410,548     93,779    145,773    183,555    173,765    221,038
# 대전광역시     1,440,094     92,255    135,890    194,905    190,213    214,434
# 울산광역시     1,098,540     73,933    109,213    117,870    136,434    174,044
# 세종특별자치시     389,978     41,643     52,212     37,131     58,906     77,263
# 경기도      13,686,731    946,337  1,320,679  1,637,135  1,900,885  2,222,316
# 강원특별자치도   1,519,545     86,475    126,958    157,315    158,402    201,983
# ...

# %% [markdown]
# ## Save

# %%
df_pop_total.to_csv('./data/202010_연령별인구.csv')
