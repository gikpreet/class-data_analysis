# %% [markdown]
# # 텍스트 마이닝
# ## koLNpy import

# %%
import konlpy
import re
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'NanumGothic'

# %%
text = open('모란이피기까지는.txt', encoding='UTF-8').read()
text
# Out:
# '저는 오늘 세계 최고 명문대 중 하나로 꼽히는 이 대학을 졸업하는 여러분들과 함께함을 영광으로 생각합니다. \n저는 대학을 졸업하지 못했습니다. 솔직히 말해, 이번이 제가 대학 졸업식을 이렇게 가까이서 보는 것은 처음입니다. \n오늘 저는 여러분들에게 제 삶 중에 있었던 3가지 이야기를 하려고 합니다. 그렇게 대단한 이야기는 아니고 그저 3가지 이야기입니다. \n\n첫 번째 이야기는 ‘이어지는 순간들’것에 관한 것입니다.\n저는 입학한지 6개월만에 리드 대학을 자퇴했지만, 그 후 18개월동안 청강하여 학교에 머물렀습니다. \n제 생모는 젊은 미혼모 대학생이었는데 저를 낳으면 다른 사람에게 입양을 시키기로 결심했습니다. \n그녀는 대학을 졸업한 사람이 저의 양부모가 되기를 간절히 원했습니다. 그래서 저는 태어나자마자 변호사 가정에 입양되기로 모든 계획이 확정되어져 있었습니다. \n내가 나타나기 전까지 절 입양시키기로 모든 계획이 확정되어져 있었습니다. \n대기자 명단에 있던 양부모님들은 한 밤 중에 “어떡하죠? 예정에 없던 사내아이가 태어났는데 그래도 입양하실 건가요?”라는 전화를 받았습니다. \n그들은 “물론이죠” 하고 대답했습니다. \n그런데 나중에 알고보니 양어머니는 대졸자도 아니었고, 양아버지는 고등학교도 졸업하지 않았습니다. \n친어머니는 입양동의서에 사인하기를 거부했습니다. \n생모는 양부모님들이 저를 꼭 대학까지 보내주겠다고 약속한 후 몇 개월이 지나서야 마음이 누그러져 받아들였습니다.\n그러나 저는 순진하게도 바로 이 곳, 스탠포드의 학비와 맞먹는 값비싼 학교를 선택했습니다. 평범한 노동자였던 부모님이 힘들게 모아뒀던 돈이 모두 제 학비로 들어갔습니다. \n6개월 후, 저는 대학 공부에 대하여 그만한 가치를 느낄 수 없었습니다. \n저는 제가 진정으로 인생에서 원하는 게 무엇인지, 그리고 대학이 그것을 실현하는데 어떻게 도움이 될 수 있을지 판단할 수 없었습니다. \n그런데도 저는 양부모님들이 평생토록 모은 재산의 전부를 제 학비로 쓰고 있었습니다.\n그래서 저는 모든 것이 다 잘 될거라고 믿고 자퇴를 결심했습니다.\n그 때 그것은 참으로 두려운 힘든 순간이었지만, 지금 뒤돌아보니 그 결정은 제 인생에서 제가 지금까지 한 결정 중 가장 탁월한 결정이었습니다. \n자퇴를 하고 저는 평소에 흥미없던 필수과목 대신 그동안 관심있게 보였던 선택과목 강의 코스만 듣기 시작했습니다. \n그렇다고 그것이 꼭 낭만적인 것만도 아니었습니다. \n\n전 기숙사에 머물 수도 없었기 때문에 친구 집 방바닥에서 자기도 했고, 한 병당 5센트씩하는 코카콜라 빈병을 반납하여 먹을 것을 사기도 했습니다. 또 매주 일요일 저녁은 맛있는 음식을 먹기 위해 시내를 지나 7마일이나 걸어서 헤어 크리슈나 사원에 가기도 했습니다.\n그런 것이 참 좋았습니다. 당시 순전히 호기심과 직관에 따라 한 일들이 후에 정말 돈으로 살 수 없는 값진 것들로 나타났습니다.\n그 당시 리드 칼리지는 아마 미국 최고의 서체 습작법 교육을 제공했던 것 같습니다. \n학교 곳곳에 붙어있는 포스터, 서랍에 붙어있는 모든 라벨들은 너무나 아름다운 수기 서체들이었습니다. \n어차피 자퇴하여 정규 과목을 듣지 않아도 되기 때문에 서체에 대해 배우기로 결심하고 서체 수업을 들었습니다. \n그 때 저는 세리프와 산 세리프체를 배웠는데, 서로 다른 문자끼리 결합될 다양한 형태의 자간으로 만들어지는 굉장히 멋진 글씨체였습니다. \n그것은 ‘과학적’인 방식으로 따라하기 힘든 아름답고, 역사적으로나 예술적으로 미묘함을 갖고 있었으며, 전 그 것에 흠뻑 매료되었습니다. \n사실, 이 때만해도 이런 것들이 제 인생에 있어서 실제로 응용가능한 희망이 되지는 못했습니다. \n그러나 10년 후, 우리가 매킨토시 컴퓨터를 처음 디자인할 때, 그것들은 고스란히 구현되어 나타났습니다. \n맥은 아마도 아름다운 서체를 가진 최초의 컴퓨터였습니다. \n만약 제가 대학에서 그 서체수업을 듣지 않았다면, 매킨토시의 복수서체 기능이나 자동 자간 맞춤 기능은 없었을 것입니다. \n따라서 윈도우도 맥을 복사한 것에 지나지 않는 바 결국 개인용 컴퓨터에도 이런 기능이 탑재될 수 없었을 것입니다.\n만약 제가 학교를 자퇴하지 않았다면 서체 수업 강의 코스를 듣지 못했을 것이고, 결국 지금의 개인용 컴퓨터도 오늘 날처럼 뛰어난 인쇄술을 가질 수 없었을 것입니다. \n물론 제가 대학에 있을 때는 그 점들이 내 미래 인생의 변환점이 되도록 연결할 수는 없었습니다. \n그러나 10년이 지난 지금 지금에서야 과거를 반추하며 그것들이 분명하게 보입니다. \n다시 말해서 지금 여러분은 미래를 내다보며 이런 사건점들을 연결질을 수 없습니다; 다만 과거를 반추하며 그 사건점들을 연결시켜 볼 수 있을 뿐이죠. \n그러므로 여러분들은 현재의 순간점들이 어떤 식으로든 당신들의 미래와 연결될 것이라는 믿음을 가져야 합니다. \n여러분들은 자신의 배짱, 운명, 인생 카르마 등 그 무엇이든지 간에 그 무엇에 믿을 가져야만 합니다. \n그 점들이 미래로 연결된다고 믿는 것은 여러분이 마음이 이끌리는 대로 살아갈 자신감을 줄 것이기 때문입니다. \n심지어 잘 닦여진 길 바깥으로 여러분들을 끌어낸다 할 지라도 말입니다. \n그리고 그것이 인생의 모든 차이를 만들 것입니다. \n\n저의 두 번째 이야기는 사랑과 상실입니다. \n저는 운 좋게도 인생에서 일찍이 제가 정말 하고 싶은 일을 발견했습니다. \n제가 20살 때, 워즈니악과 나는 부모님의 차고에서 애플을 창업했습니다. \n우리는 각고의 노력 끝에 차고에서 2명으로 시작한 애플은 10년 후에 4,000명의 직원 거느린 2백억달러짜리 기업이 되었습니다. \n제 나이 30살이 되기 1년 전인 29살, 우리는 최고의 작품인 매킨토시를 출시했습니다. 그러나 이듬해 저는 해고당했습니다.\n어떻게 당신이 세운 회사에서 당신이 해고 될 수 있습니까? \n당시, 애플이 점점 성장하면서, 우리들은 저와 잘 맞는다고 생각되는 유능한 경영자를 고용했습니다. 그리고 처음 1년은 괜찮았습니다. \n그런데 미래에 대한 우리의 비전은 서로 어긋나기 시작했고, 결국 우리 둘의 사이도 무너지기시작했습니다. \n이 때 우리 회사 이사회는 그(존 스컬리)의 편을 들었습니다. \n저는 30살에 쫓겨나야만 했습니다. 그것도 아주 철저히 공개적으로. \n제 성년기의 중심이었던 것이 사라졌고, 그야말로 참담했습니다.\n정말 몇 개월 동안 아무것도 할 수 없었습니다.\n이전 세대의 기업가들을 실망시킨 기분이 들었고, 마치 달리기 계주에서 바톤을 놓친 선수 같은 생각이 들었습니다.\n데이비드 패커드(HP의 공동 창업자)와 밥 노이스(인텔의 공동 창업자)를 만나 이렇게 실패한 것에 대해 사과하려 했습니다.\n저는 공공의 실패작이었고, 심지어 실리콘 밸리에서 달아날 생각도 했습니다. \n하지만 점점 분명해졌던 건 제가 여전히 제가 했던 일을 사랑했다는 것입니다. \n애플에서 예기치 못한 일들이 저는 바꾸지 못했습니다. \n거절당했지만, 여전히 사랑에 빠져있었습니다. \n그래서 다시 시작하기로 했습니다. \n그때는 몰랐지만, 애플에서 해고된 것이 제 인생에서 가장 큰 행운이었습니다.\n성공해야한다는 부담감은 새로 시작하는 사람의 가뿐한 마음으로, 즉 상황에 대해 덜 확신하는 태도로 바뀌었습니다. \n덕분에 제 인생에서 가장 창의적인 시기로 진입하는 데 큰 어려움이 없었습니다. \n그 후 5년간, 넥스트란 회사와 픽사란 또 다른 회사를 창업했고, 제 아내가 되어준 굉장한 여성과 사랑에 빠졌습니다. \n픽사는 곧 이어 세계 최초의 애니메이션 영화인 토이스토리를 만들었고, 지금은 세계에서 가장 성공적인 애니메이션 스튜디오입니다.\n상황이 극적으로 역전되어, 애플이 넥스트를 사들이면서 전 애플로 돌아왔습니다. 넥스트에서 개발한 기술은 현재 부흥기를 맞이한 애플의 중추적인 역할을 하고 있습니다. \n또한 로렌과 저는 행복한 가정을 갖게 되었습니다.\n애플에서 해고당하지 않았더라면 이런 일들이 결코 일어나지 않았을 것입니다. \n그것은 정말 독하고 쓰디 쓴 약이었지만, 환자에게는 이런 것들이 필요한 것 같기도 합니다. \n때론 삶이 벽돌로 뒤통수를 때릴  ...

# %%
# 한글이 아닌 모든 문자를 공백으로 변환
clean_text = re.sub('[^가-힣]', ' ', text)
clean_text
# Out:
# '저는 오늘 세계 최고 명문대 중 하나로 꼽히는 이 대학을 졸업하는 여러분들과 함께함을 영광으로 생각합니다   저는 대학을 졸업하지 못했습니다  솔직히 말해  이번이 제가 대학 졸업식을 이렇게 가까이서 보는 것은 처음입니다   오늘 저는 여러분들에게 제 삶 중에 있었던  가지 이야기를 하려고 합니다  그렇게 대단한 이야기는 아니고 그저  가지 이야기입니다    첫 번째 이야기는  이어지는 순간들 것에 관한 것입니다  저는 입학한지  개월만에 리드 대학을 자퇴했지만  그 후   개월동안 청강하여 학교에 머물렀습니다   제 생모는 젊은 미혼모 대학생이었는데 저를 낳으면 다른 사람에게 입양을 시키기로 결심했습니다   그녀는 대학을 졸업한 사람이 저의 양부모가 되기를 간절히 원했습니다  그래서 저는 태어나자마자 변호사 가정에 입양되기로 모든 계획이 확정되어져 있었습니다   내가 나타나기 전까지 절 입양시키기로 모든 계획이 확정되어져 있었습니다   대기자 명단에 있던 양부모님들은 한 밤 중에  어떡하죠  예정에 없던 사내아이가 태어났는데 그래도 입양하실 건가요  라는 전화를 받았습니다   그들은  물론이죠  하고 대답했습니다   그런데 나중에 알고보니 양어머니는 대졸자도 아니었고  양아버지는 고등학교도 졸업하지 않았습니다   친어머니는 입양동의서에 사인하기를 거부했습니다   생모는 양부모님들이 저를 꼭 대학까지 보내주겠다고 약속한 후 몇 개월이 지나서야 마음이 누그러져 받아들였습니다  그러나 저는 순진하게도 바로 이 곳  스탠포드의 학비와 맞먹는 값비싼 학교를 선택했습니다  평범한 노동자였던 부모님이 힘들게 모아뒀던 돈이 모두 제 학비로 들어갔습니다    개월 후  저는 대학 공부에 대하여 그만한 가치를 느낄 수 없었습니다   저는 제가 진정으로 인생에서 원하는 게 무엇인지  그리고 대학이 그것을 실현하는데 어떻게 도움이 될 수 있을지 판단할 수 없었습니다   그런데도 저는 양부모님들이 평생토록 모은 재산의 전부를 제 학비로 쓰고 있었습니다  그래서 저는 모든 것이 다 잘 될거라고 믿고 자퇴를 결심했습니다  그 때 그것은 참으로 두려운 힘든 순간이었지만  지금 뒤돌아보니 그 결정은 제 인생에서 제가 지금까지 한 결정 중 가장 탁월한 결정이었습니다   자퇴를 하고 저는 평소에 흥미없던 필수과목 대신 그동안 관심있게 보였던 선택과목 강의 코스만 듣기 시작했습니다   그렇다고 그것이 꼭 낭만적인 것만도 아니었습니다    전 기숙사에 머물 수도 없었기 때문에 친구 집 방바닥에서 자기도 했고  한 병당  센트씩하는 코카콜라 빈병을 반납하여 먹을 것을 사기도 했습니다  또 매주 일요일 저녁은 맛있는 음식을 먹기 위해 시내를 지나  마일이나 걸어서 헤어 크리슈나 사원에 가기도 했습니다  그런 것이 참 좋았습니다  당시 순전히 호기심과 직관에 따라 한 일들이 후에 정말 돈으로 살 수 없는 값진 것들로 나타났습니다  그 당시 리드 칼리지는 아마 미국 최고의 서체 습작법 교육을 제공했던 것 같습니다   학교 곳곳에 붙어있는 포스터  서랍에 붙어있는 모든 라벨들은 너무나 아름다운 수기 서체들이었습니다   어차피 자퇴하여 정규 과목을 듣지 않아도 되기 때문에 서체에 대해 배우기로 결심하고 서체 수업을 들었습니다   그 때 저는 세리프와 산 세리프체를 배웠는데  서로 다른 문자끼리 결합될 다양한 형태의 자간으로 만들어지는 굉장히 멋진 글씨체였습니다   그것은  과학적 인 방식으로 따라하기 힘든 아름답고  역사적으로나 예술적으로 미묘함을 갖고 있었으며  전 그 것에 흠뻑 매료되었습니다   사실  이 때만해도 이런 것들이 제 인생에 있어서 실제로 응용가능한 희망이 되지는 못했습니다   그러나   년 후  우리가 매킨토시 컴퓨터를 처음 디자인할 때  그것들은 고스란히 구현되어 나타났습니다   맥은 아마도 아름다운 서체를 가진 최초의 컴퓨터였습니다   만약 제가 대학에서 그 서체수업을 듣지 않았다면  매킨토시의 복수서체 기능이나 자동 자간 맞춤 기능은 없었을 것입니다   따라서 윈도우도 맥을 복사한 것에 지나지 않는 바 결국 개인용 컴퓨터에도 이런 기능이 탑재될 수 없었을 것입니다  만약 제가 학교를 자퇴하지 않았다면 서체 수업 강의 코스를 듣지 못했을 것이고  결국 지금의 개인용 컴퓨터도 오늘 날처럼 뛰어난 인쇄술을 가질 수 없었을 것입니다   물론 제가 대학에 있을 때는 그 점들이 내 미래 인생의 변환점이 되도록 연결할 수는 없었습니다   그러나   년이 지난 지금 지금에서야 과거를 반추하며 그것들이 분명하게 보입니다   다시 말해서 지금 여러분은 미래를 내다보며 이런 사건점들을 연결질을 수 없습니다  다만 과거를 반추하며 그 사건점들을 연결시켜 볼 수 있을 뿐이죠   그러므로 여러분들은 현재의 순간점들이 어떤 식으로든 당신들의 미래와 연결될 것이라는 믿음을 가져야 합니다   여러분들은 자신의 배짱  운명  인생 카르마 등 그 무엇이든지 간에 그 무엇에 믿을 가져야만 합니다   그 점들이 미래로 연결된다고 믿는 것은 여러분이 마음이 이끌리는 대로 살아갈 자신감을 줄 것이기 때문입니다   심지어 잘 닦여진 길 바깥으로 여러분들을 끌어낸다 할 지라도 말입니다   그리고 그것이 인생의 모든 차이를 만들 것입니다    저의 두 번째 이야기는 사랑과 상실입니다   저는 운 좋게도 인생에서 일찍이 제가 정말 하고 싶은 일을 발견했습니다   제가   살 때  워즈니악과 나는 부모님의 차고에서 애플을 창업했습니다   우리는 각고의 노력 끝에 차고에서  명으로 시작한 애플은   년 후에      명의 직원 거느린  백억달러짜리 기업이 되었습니다   제 나이   살이 되기  년 전인   살  우리는 최고의 작품인 매킨토시를 출시했습니다  그러나 이듬해 저는 해고당했습니다  어떻게 당신이 세운 회사에서 당신이 해고 될 수 있습니까   당시  애플이 점점 성장하면서  우리들은 저와 잘 맞는다고 생각되는 유능한 경영자를 고용했습니다  그리고 처음  년은 괜찮았습니다   그런데 미래에 대한 우리의 비전은 서로 어긋나기 시작했고  결국 우리 둘의 사이도 무너지기시작했습니다   이 때 우리 회사 이사회는 그 존 스컬리 의 편을 들었습니다   저는   살에 쫓겨나야만 했습니다  그것도 아주 철저히 공개적으로   제 성년기의 중심이었던 것이 사라졌고  그야말로 참담했습니다  정말 몇 개월 동안 아무것도 할 수 없었습니다  이전 세대의 기업가들을 실망시킨 기분이 들었고  마치 달리기 계주에서 바톤을 놓친 선수 같은 생각이 들었습니다  데이비드 패커드   의 공동 창업자 와 밥 노이스 인텔의 공동 창업자 를 만나 이렇게 실패한 것에 대해 사과하려 했습니다  저는 공공의 실패작이었고  심지어 실리콘 밸리에서 달아날 생각도 했습니다   하지만 점점 분명해졌던 건 제가 여전히 제가 했던 일을 사랑했다는 것입니다   애플에서 예기치 못한 일들이 저는 바꾸지 못했습니다   거절당했지만  여전히 사랑에 빠져있었습니다   그래서 다시 시작하기로 했습니다   그때는 몰랐지만  애플에서 해고된 것이 제 인생에서 가장 큰 행운이었습니다  성공해야한다는 부담감은 새로 시작하는 사람의 가뿐한 마음으로  즉 상황에 대해 덜 확신하는 태도로 바뀌었습니다   덕분에 제 인생에서 가장 창의적인 시기로 진입하는 데 큰 어려움이 없었습니다   그 후  년간  넥스트란 회사와 픽사란 또 다른 회사를 창업했고  제 아내가 되어준 굉장한 여성과 사랑에 빠졌습니다   픽사는 곧 이어 세계 최초의 애니메이션 영화인 토이스토리를 만들었고  지금은 세계에서 가장 성공적인 애니메이션 스튜디오입니다  상황이 극적으로 역전되어  애플이 넥스트를 사들이면서 전 애플로 돌아왔습니다  넥스트에서 개발한 기술은 현재 부흥기를 맞이한 애플의 중추적인 역할을 하고 있습니다   또한 로렌과 저는 행복한 가정을 갖게 되었습니다  애플에서 해고당하지 않았더라면 이런 일들이 결코 일어나지 않았을 것입니다   그것은 정말 독하고 쓰디 쓴 약이었지만  환자에게는 이런 것들이 필요한 것 같기도 합니다   때론 삶이 벽돌로 뒤통수를 때릴 때도 있습니다   믿음을 잃지 마세요  저는 제가 했던 일을 사랑하지 않았다면 앞으로 꿋꿋이 나아가지 못했으리라 생각합니다   정말 ...

# %%
# 명사 추출
nouns = konlpy.tag.Hannanum().nouns(clean_text)
nouns
# Out:
# ['저',
#  '오늘',
#  '세계',
#  '최고',
#  '명문대',
#  '중',
#  '하나',
#  '대학',
#  '졸업',
#  '여러분들',
#  '영광',
#  '생각',
#  '저',
#  '대학',
#  '졸업',
#  '말',
#  '이번',
#  '저',
#  '대학',
#  '졸업식',
#  '가까이',
#  '것',
#  '처음',
#  '오늘',
#  '저',
#  '여러분들에',
#  '저',
#  '삶',
#  '중',
#  '가지',
#  '이야기',
#  '대',
#  '한',
#  '이야기',
#  '가지',
#  '이야기',
#  '첫',
#  '번',
#  '이야기',
#  '순간들',
#  '것',
#  '것',
#  '저',
#  '입학한지',
#  '개월',
#  '리드',
#  '대학',
#  '자퇴했지만',
#  '후',
#  '개월',
#  '청강하',
#  '학교',
#  '저',
#  '생모',
#  '미혼모',
#  '대학생',
#  '저',
#  '사람',
#  '입양',
#  '결심',
#  '그녀',
#  '대학',
#  '졸업',
#  '사람',
#  '저',
#  '양부모',
#  '저',
#  '변호사',
#  '가정',
#  '입양',
#  '계획',
#  '확정',
#  '나',
#  '전',
#  '절',
#  '입양',
#  '계획',
#  '확정',
#  '대',
#  '명단',
#  '양부모님',
#  '밤',
#  '중',
#  '예정',
#  '사내아이',
#  '입양',
#  '것',
#  '라',
#  '전화',
#  '그',
#  '물론',
#  '대답',
#  '나중',
#  '어머니',
#  '대졸자',
#  '양아버지',
#  '고등학교',
#  '졸업',
#  '친어머니',
#  '입양동의서',
#  '사인하기',
#  '거부',
#  '생모',
#  '양부모님',
#  '저',
#  '대학',
#  '약속',
#  '후',
#  '몇',
#  '개월',
#  '마음',
#  '저',
#  '순진',
#  '곳',
#  '스탠포드',
#  '학비',
#  '학교',
#  '선택',
#  '평범',
#  '노동자',
#  '부모님',
#  '돈',
#  '저',
#  '학비',
#  '개월',
#  '후',
#  '저',
#  '대학',
#  '공부',
#  '가치',
#  '수',
#  '저',
#  '저',
#  '진정',
#  '인생',
#  '것',
#  '무엇',
#  '대학',
#  '그것',
#  '실현',
#  '도움',
#  '수',
#  '지',
#  '판단',
#  '수',
#  '저',
#  '양부모님',
#  '평생토록',
#  '재산',
#  '전부',
#  '저',
#  '학비',
#  '저',
#  '것',
#  '것',
#  '자퇴',
#  '결심',
#  '때',
#  '그것',
#  '순간',
#  '결정',
#  '저',
#  '인생',
#  '저',
#  '결정',
#  '중',
#  '탁월',
#  '결정',
#  '자퇴',
#  '저',
#  '평소',
#  '흥미',
#  '필수과목',
#  '대',
#  '그동안',
#  '관심',
#  '선택과목',
#  '강',
#  '코스',
#  '시작',
#  '그것',
#  '낭만적',
#  '것',
#  '전',
#  '기숙사',
#  '수',
#  '때문',
#  '친구',
#  '집',
#  '방바닥',
#  '자기',
#  '병',
#  '센트씩하',
#  '코카콜라',
#  '빈병',
#  '반납',
#  '것',
#  '일요일',
#  '저녁',
#  '음식',
#  '시내',
#  '마일',
#  '크리슈나',
#  '사원',
#  '것',
#  '당시',
#  '호',
#  '직관',
#  '들',
#  '후',
#  '돈',
#  '수',
#  '것들',
#  '당시',
#  '리드',
#  '칼리지',
#  '미국',
#  '최고',
#  '서체',
#  '습작법',
#  '교육',
#  '제공',
#  '것',
#  '학교',
#  '곳곳',
#  '포스터',
#  '서랍',
#  '라벨들',
#  '수',
#  '서체들이',
#  '자퇴하',
#  '정규',
#  '과목',
#  '때문',
#  '서체',
#  '결심',
#  '서체',
#  '수업',
#  '때',
#  '저',
#  '세리프',
#  '세리프체',
#  '문자',
#  '결합',
#  '다양한',
#  '형태',
#  '자',
#  '글씨체',
#  '그것',
#  '과학적',
#  '방식',
#  '역사적',
#  '예술적',
#  '미묘함',
#  '전',
#  '것',
#  '매료',
#  '때만해도',
#  '것들',
#  '저',
#  '인생',
#  '응용가능',
#  '희망',
#  '년',
#  '후',
#  '우리',
#  '매킨토시',
#  '컴퓨터',
#  '디자인',
#  '때',
#  '그것들',
#  '구현',
#  '맥',
#  '서체',
#  '최초',
#  '컴퓨터',
#  '저',
#  '대학',
#  '서체수업',
#  '않았다',
#  '매킨토시',
#  '복수서체',
#  '기능',
#  '자동',
#  '기능',
#  '것',
#  '윈도우',
#  '맥',
#  '복사',
#  '것',
#  '바',
#  '개인용',
#  '컴퓨터',
#  '기능',
#  '탑재',
#  '수',
#  '것',
#  '저',
#  '학교',
#  '자퇴하',
#  '않았다',
#  '서체',
#  '수업',
#  '강',
#  '코스',
#  '것',
#  '지금',
#  '개인용',
#  '컴퓨터',
#  '오늘',
#  '날',
#  '인쇄술',
#  '수',
#  '것',
#  '저',
#  '대학',
#  '때',
#  '점',
#  '미래',
#  '인생',
#  '변환점',
#  '연결',
#  '수',
#  '년',
#  '지금',
#  '지금',
#  '과거',
#  '반추',
#  '그것들',
#  '분명',
#  '말',
#  '여러분',
#  '미래',
#  '사건점',
#  '연결질',
#  '수',
#  '과거',
#  '반추',
#  '사건점',
#  '연결',
#  '수',
#  '뿐',
#  '여러분들',
#  '현재',
#  '순간점',
#  '식',
#  '당신들',
#  '미래',
#  '연결',
#  '것',
#  '믿음',
#  '여러분들',
#  '자신',
#  '배짱',
#  '운명',
#  '인생',
#  '카르',
#  '등',
#  '무엇',
#  '간',
#  '무엇',
#  '점',
#  '미래',
#  '연결',
#  '것',
#  '여러분',
#  '마음',
#  '리',
#  '대',
#  '자신감',
#  '것',
#  '때문',
#  '길',
#  '바깥',
#  '여러분들',
#  '지',
#  '말',
#  '그것',
#  '인생',
#  '차이',
#  '것',
#  '저',
#  '두',
#  '번',
#  '이야기',
#  '사랑',
#  '상실',
#  '저',
#  '인생',
#  '저',
#  '일',
#  '발견',
#  '저',
#  '때',
#  '워즈니악',
#  '나',
#  '부모님',
#  '차고',
#  '애플',
#  '창업',
#  '우리',
#  '각고',
#  '노력',
#  '끝',
#  '차고',
#  '명',
#  '시작',
#  '애플',
#  '년',
#  '후',
#  '명',
#  '직원',
#  '백억달러',
#  '기업',
#  '저',
#  '나',
#  '살',
#  '년',
#  '전',
#  '살',
#  '우리',
#  '최고',
#  '작품',
#  '매킨토시',
#  '출시',
#  '이듬해',
#  '저',
#  '해고',
#  '당신',
#  '회사',
#  '당신',
#  '수',
#  '당시',
#  '애플',
#  '성장',
#  '우리들',
#  '저',
#  '생각',
#  '유능',
#  '경영자',
#  '고용',
#  '년',
#  '미래',
#  '우리',
#  '비전',
#  '시작',
#  '우리',
#  '둘',
#  '사이',
#  '무너지기시작했습니다',
#  '때',
#  '우리',
#  '회사',
#  '이사회',
#  '스컬리',
#  '의',
#  '편',
#  '저',
#  '살',
#  '그것',
#  '공개적',
#  '저',
#  '성년기',
#  '중심',
#  '것',
#  '참담',
#  '몇',
#  '개월',
#  '동안',
#  '아무것',
#  '수',
#  '이전',
#  '세대',
#  '기업가들',
#  '실망',
#  '기분',
#  '계주',
#  '바톤',
#  '수',
#  '생각',
#  '데이비드',
#  '패커드',
#  '의',
#  '공동',
#  '창업자',
#  '밥',
#  '노이스',
#  '인텔',
#  '공동',
#  '창업자',
#  '를',
#  '실패한',
#  '것',
#  '사과',
#  '저',
#  '공공',
#  '실패작',
#  '실리콘',
#  '리',
#  '생각',
#  '분명',
#  '거',
#  '저',
#  '저',
#  '일',
#  '사랑',
#  '것',
#  '애플',
#  '예기치',
#  '들',
#  '저',
#  '거절',
#  '사랑',
#  '시작',
#  '그때',
#  '애플',
#  '해',
#  '것',
#  '저',
#  '인생',
#  '행운',
#  '성공',
#  '부담감',
#  '시작',
#  '사람',
#  '가뿐',
#  '마음',
#  '상황',
#  '확신',
#  '태도',
#  '덕분',
#  '저',
#  '인생',
#  '창의적',
#  '시',
#  '진입',
#  '데',
#  '어려움',
#  '후',
#  '년',
#  '넥스트',
#  '회사',
#  '픽사란',
#  '회사',
#  '창업',
#  '저',
#  '아내',
#  '굉장',
#  '여성',
#  '사랑',
#  '픽사',
#  '이',
#  '세계',
#  '최초',
#  '애니메이션',
#  '영화',
#  '토이스토리',
#  '지금',
#  '세계',
#  '성공적',
#  '애니메이션',
#  '스튜디오',
#  '상황',
#  '극',
#  '역전',
#  '애플',
#  '넥스트',
#  '전',
#  '애플',
#  '넥스트',
#  '개발',
#  '기술',
#  '부흥기',
#  '맞이',
#  '애플',
#  '중추적',
#  '역할',
#  '로렌',
#  '저',
#  '행복',
#  '가정',
#  '애플',
#  '해고',
#  '들',
#  '것',
#  '그것',
#  '약',
#  '환자',
#  '것들',
#  '필요',
#  '것',
#  '때론',
#  '삶',
#  '벽돌',
#  '뒤통수',
#  '때',
#  '믿음',
#  '저',
#  '저',
#  '일',
#  '사랑',
#  '않았다',
#  '앞',
#  '생각',
#  '정말',
#  '일',
#  '찾으세요',
#  '사랑',
#  '사람',
#  '것',
#  '일',
#  '당신',
#  '일',
#  '당신',
#  '인생',
#  '부분',
#  '것',
#  '진정',
#  '만족',
#  '방법',
#  '위대한',
#  '일',
#  '수',
#  '일',
#  '매진',
#  '뿐',
#  '위대한',
#  '일',
#  '당신',
#  '지금하',
#  '일',
#  '사랑',
#  '것',
#  '당신',
#  '그것',
#  '발견',
#  '그것',
#  '지금',
#  '현실',
#  '안주',
#  '마음',
#  '그것',
#  '순간',
#  '것',
#  '관계',
#  '시간',
#  '것',
#  '때',
#  '노력',
#  '안주',
#  '세',
#  '번',
#  '이야기',
#  '죽음',
#  '것',
#  '저',
#  '때',
#  '구절',
#  '적',
#  '하루',
#  '마지막',
#  '것',
#  '사람',
#  '것',
#  '그것',
#  '저',
#  '인상적',
#  '후',
#  '년',
#  '동안',
#  '아침',
#  '거울',
#  '스스로',
#  '오늘',
#  '인생',
#  '마지막',
#  '날',
#  '오늘',
#  '일',
#  '것',
#  '라',
#  '대답',
#  '날',
#  '변화',
#  '필요',
#  '나',
#  '것',
#  '것',
#  '기억',
#  '것',
#  '인생',
#  '결정',
#  '것',
#  '수',
#  '지금',
#  '것',
#  '중',
#  '중요',
#  '도구',
#  '외부',
#  '기대',
#  '자부심',
#  '당혹',
#  '실패',
#  '두려움',
#  '따위',
#  '죽음',
#  '앞',
#  '중요',
#  '것',
#  '당신',
#  '것',
#  '기억',
#  '것',
#  '무엇',
#  '지',
#  '두려움',
#  '수',
#  '방법',
#  '당신',
#  '몸',
#  '여러분',
#  '마음',
#  '저',
#  '년',
#  '전',
#  '진단',
#  '아침',
#  '시',
#  '반',
#  '컴퓨터',
#  '단층촬영',
#  '검사',
#  '저',
#  '췌장',
#  '종양',
#  '수',
#  '저',
#  '그때',
#  '췌장',
#  '뭔지',
#  '의사들',
#  '종양',
#  '치료',
#  '개월',
#  '개월정도만',
#  '살',
#  '수',
#  '말',
#  '주치의',
#  '집',
#  '신변정리',
#  '그것',
#  '죽',
#  '준비',
#  '의사들',
#  '코드',
#  '그것',
#  '당신',
#  '아이들',
#  '당신',
#  '년',
#  '말',
#  '것들',
#  '몇',
#  '달',
#  '안',
#  '말',
#  '뜻',
#  '그것',
#  '것',
#  '정리',
#  '가능',
#  '한',
#  '당신',
#  '가족들',
#  '충격',
#  '뜻',
#  '그것',
#  '당신',
#  '작별인사',
#  '말',
#  '저',
#  '하루종일',
#  '각종',
#  '진단',
#  '그날',
#  '저녁',
#  '이후',
#  '조직',
#  '검사',
#  '목구멍',
#  '내시경',
#  '내시경',
#  '위',
#  '장치',
#  '속',
#  '췌장',
#  '바늘',
#  '종양',
#  '약간',
#  '세포',
#  '추출',
#  '방식',
#  '저',
#  '마취',
#  '상태',
#  '거기',
#  '아내',
#  '전해주길',
#  '현미경',
#  '세포',
#  '검사',
#  '때',
#  '의사들',
#  '수술',
#  '치료',
#  '가능',
#  '희귀한',
#  '형태',
#  '췌장암',
#  '판명',
#  '전',
#  '수술',
#  '건강',
#  '이것',
#  '저',
#  '죽음',
#  '맞이',
#  '경우',
#  '앞',
#  '몇',
#  '십년',
#  '경험',
#  '죽',
#  '유용',
#  '것',
#  '머리',
#  '때',
#  '명확',
#  '말',
#  '수',
#  '아무',
#  '천국',
#  '사람',
#  '그곳',
#  '죽음',
#  '우리',
#  '모두',
#  '최종',
#  '목적지',
#  '아무',
#  '그것',
#  '수',
#  '삶',
#  '최고',
#  '작품',
#  '죽음',
#  '이',
#  '죽음',
#  '삶',
#  '변화',
#  '요인',
#  '죽음',
#  '것',
#  '것',
#  '극단적',
#  '죄송',
#  '이것',
#  '엄연',
#  '사실',
#  '여러분',
#  '삶',
#  '제한',
#  '누군가',
#  '삶',
#  '낭비',
#  '사람',
#  '결과물',
#  '불과',
#  '삶',
#  '신조',
#  '소음',
#  '불과',
#  '사람',
#  '의견',
#  '여러분',
#  '내면',
#  '목소리',
#  '중요',
#  '것',
#  '마음',
#  '직관',
#  '용기',
#  '것',
#  '마음',
#  '직관',
#  '당신',
#  '진짜',
#  '무엇',
#  '나머지',
#  '것들',
#  '부수적',
#  '것',
#  '저',
#  '때',
#  '저',
#  '나',
#  '또래',
#  '만',
#  '대',
#  '한',
#  '출판물',
#  '지구',
#  '백',
#  '라',
#  '책',
#  '책',
#  '여기',
#  '먼로',
#  '파크',
#  '스튜어트',
#  '브랜드',
#  '사람',
#  '책',
#  '그',
#  '책',
#  '자신',
#  '시적',
#  '감정',
#  '때',
#  '개인용',
#  '컴퓨터',
#  '데스크톱',
#  '판',
#  '도입',
#  '전',
#  '년대',
#  '후반',
#  '타자',
#  '가위',
#  '폴라로이드',
#  '카메라',
#  '이용',
#  '구글',
#  '전',
#  '년',
#  '전',
#  '문고판',
#  '형태',
#  '구글',
#  '스튜어트',
#  '그',
#  '팀',
#  '지구백',
#  '를',
#  '몇',
#  '번',
#  '개정판',
#  '발행',
#  '예정',
#  '판',
#  '출판',
#  '후',
#  '최종판',
#  '때',
#  '년대',
#  '중반',
#  '저',
#  '여러분',
#  '나',
#  '때',
#  '최종판',
#  '뒤쪽',
#  '표지',
#  '아침',
#  '시골길',
#  '사진',
#  '당신',
#  '모험',
#  '히치하이킹',
#  '생각',
#  '것',
#  '밑',
#  '말',
#  '갈망',
#  '우직하',
#  '갈망',
#  '우직하라',
#  '그것',
#  '그',
#  '마지막',
#  '사',
#  '인사',
#  '전',
#  '저',
#  '자신',
#  '그러길',
#  '졸업',
#  '출발',
#  ...]

# %%
# DataFrame으로 변환
df_words = pd.DataFrame({'word': nouns})
df_words.head()
# Out:
#   word
# 0    저
# 1   오늘
# 2   세계
# 3   최고
# 4  명문대

# %%
# 2글자 이하인 단어 삭제
df_words['count'] = df_words['word'].str.len()
df_words = df_words[(df_words['count'] >= 2)]
# query() 메소드 사용
#df_words = df_words.query('count >= 2')

# count 컬럼을 1로 수정
df_words['count'] = 1
df_words
# Out:
#      word  count
# 1      오늘      1
# 2      세계      1
# 3      최고      1
# 4     명문대      1
# 6      하나      1
# ...   ...    ...
# 996    자신      1
# 997   그러길      1
# 998    졸업      1
# 999    출발      1
# 1000  여러분      1
#
# [678 rows x 2 columns]

# %%
# groupby로 집계
df_wc = df_words.groupby(by='word',as_index=False).agg(count=('word','count')).sort_values('count', ascending=False)
df_wc
# Out:
#       word  count
# 50      그것     17
# 83      당신     14
# 285     인생     12
# 88      대학     10
# 233     애플      9
# ..     ...    ...
# 152    변호사      1
# 151     벽돌      1
# 150   백억달러      1
# 149     배짱      1
# 407  히치하이킹      1
#
# [408 rows x 2 columns]

# %%
sns.barplot(data=df_wc.head(20),y='word',x='count')
# Out:
# <Axes: xlabel='count', ylabel='word'>

# %%
# wordcloud
dic_word = df_wc.set_index('word').to_dict()['count']
dic_word
# Out:
# {'그것': 17,
#  '당신': 14,
#  '인생': 12,
#  '대학': 10,
#  '애플': 9,
#  '사람': 9,
#  '여러분': 7,
#  '사랑': 7,
#  '마음': 7,
#  '죽음': 7,
#  '우리': 7,
#  '개월': 6,
#  '생각': 6,
#  '이야기': 6,
#  '지금': 6,
#  '컴퓨터': 6,
#  '오늘': 5,
#  '시작': 5,
#  '것들': 5,
#  '미래': 5,
#  '무엇': 5,
#  '졸업': 5,
#  '서체': 5,
#  '회사': 4,
#  '연결': 4,
#  '여러분들': 4,
#  '최고': 4,
#  '입양': 4,
#  '결정': 4,
#  '학교': 4,
#  '중요': 3,
#  '당시': 3,
#  '넥스트': 3,
#  '췌장': 3,
#  '때문': 3,
#  '자신': 3,
#  '직관': 3,
#  '마지막': 3,
#  '매킨토시': 3,
#  '종양': 3,
#  '의사들': 3,
#  '세계': 3,
#  '아침': 3,
#  '않았다': 3,
#  '기능': 3,
#  '양부모님': 3,
#  '개인용': 3,
#  '결심': 3,
#  '검사': 3,
#  '학비': 3,
#  '형태': 3,
#  '수술': 2,
#  '맞이': 2,
#  '계획': 2,
#  '위대한': 2,
#  '세포': 2,
#  '리드': 2,
#  '진단': 2,
#  '분명': 2,
#  '수업': 2,
#  '차고': 2,
#  '순간': 2,
#  '창업': 2,
#  '두려움': 2,
#  '동안': 2,
#  '창업자': 2,
#  '가능': 2,
#  '필요': 2,
#  '진정': 2,
#  '이것': 2,
#  '방법': 2,
#  '해고': 2,
#  '부모님': 2,
#  '사건점': 2,
#  '변화': 2,
#  '자퇴': 2,
#  '자퇴하': 2,
#  '방식': 2,
#  '작품': 2,
#  '공동': 2,
#  '발견': 2,
#  '반추': 2,
#  '구글': 2,
#  '저녁': 2,
#  '믿음': 2,
#  '상황': 2,
#  '생모': 2,
#  '확정': 2,
#  '불과': 2,
#  '그것들': 2,
#  '가지': 2,
#  '아무': 2,
#  '가정': 2,
#  '그때': 2,
#  '안주': 2,
#  '내시경': 2,
#  '치료': 2,
#  '년대': 2,
#  '아내': 2,
#  '애니메이션': 2,
#  '노력': 2,
#  '코스': 2,
#  '예정': 2,
#  '과거': 2,
#  '갈망': 2,
#  '최초': 2,
#  '최종판': 2,
#  '대답': 2,
#  '스튜어트': 2,
#  '기억': 2,
#  '이후': 1,
#  '흥미': 1,
#  '인사': 1,
#  '이전': 1,
#  '인상적': 1,
#  '이용': 1,
#  '현미경': 1,
#  '외부': 1,
#  '행복': 1,
#  '여기': 1,
#  '행운': 1,
#  '이사회': 1,
#  '인쇄술': 1,
#  '희귀한': 1,
#  '희망': 1,
#  '엄연': 1,
#  '인텔': 1,
#  '일요일': 1,
#  '어머니': 1,
#  '어려움': 1,
#  '현실': 1,
#  '역사적': 1,
#  '여러분들에': 1,
#  '연결질': 1,
#  '용기': 1,
#  '우리들': 1,
#  '우직하': 1,
#  '예술적': 1,
#  '예기치': 1,
#  '환자': 1,
#  '우직하라': 1,
#  '영화': 1,
#  '운명': 1,
#  '영광': 1,
#  '워즈니악': 1,
#  '윈도우': 1,
#  '후반': 1,
#  '현재': 1,
#  '확신': 1,
#  '유능': 1,
#  '역할': 1,
#  '유용': 1,
#  '음식': 1,
#  '응용가능': 1,
#  '의견': 1,
#  '역전': 1,
#  '이듬해': 1,
#  '요인': 1,
#  '이번': 1,
#  '여성': 1,
#  '판단': 1,
#  '재산': 1,
#  '입양동의서': 1,
#  '포스터': 1,
#  '충격': 1,
#  '평소': 1,
#  '출판물': 1,
#  '출판': 1,
#  '출시': 1,
#  '출발': 1,
#  '추출': 1,
#  '최종': 1,
#  '입학한지': 1,
#  '폴라로이드': 1,
#  '청강하': 1,
#  '천국': 1,
#  '처음': 1,
#  '찾으세요': 1,
#  '창의적': 1,
#  '참담': 1,
#  '평생토록': 1,
#  '췌장암': 1,
#  '친구': 1,
#  '친어머니': 1,
#  '파크': 1,
#  '토이스토리': 1,
#  '판명': 1,
#  '태도': 1,
#  '탑재': 1,
#  '탁월': 1,
#  '타자': 1,
#  '크리슈나': 1,
#  '코카콜라': 1,
#  '패커드': 1,
#  '코드': 1,
#  '평범': 1,
#  '칼리지': 1,
#  '카메라': 1,
#  '카르': 1,
#  '차이': 1,
#  '진짜': 1,
#  '표지': 1,
#  '하루종일': 1,
#  '제한': 1,
#  '제공': 1,
#  '정말': 1,
#  '정리': 1,
#  '정규': 1,
#  '전화': 1,
#  '전해주길': 1,
#  '전부': 1,
#  '장치': 1,
#  '작별인사': 1,
#  '자퇴했지만': 1,
#  '자신감': 1,
#  '자부심': 1,
#  '자동': 1,
#  '자기': 1,
#  '조직': 1,
#  '졸업식': 1,
#  '진입': 1,
#  '하루': 1,
#  '직원': 1,
#  '픽사': 1,
#  '픽사란': 1,
#  '필수과목': 1,
#  '지금하': 1,
#  '지구백': 1,
#  '지구': 1,
#  '중추적': 1,
#  '양아버지': 1,
#  '중심': 1,
#  '중반': 1,
#  '준비': 1,
#  '하나': 1,
#  '주치의': 1,
#  '죄송': 1,
#  '가까이': 1,
#  '순진': 1,
#  '양부모': 1,
#  '낭비': 1,
#  '당혹': 1,
#  '당신들': 1,
#  '단층촬영': 1,
#  '다양한': 1,
#  '누군가': 1,
#  '노이스': 1,
#  '노동자': 1,
#  '내면': 1,
#  '낭만적': 1,
#  '머리': 1,
#  '나중': 1,
#  '나머지': 1,
#  '기업가들': 1,
#  '기업': 1,
#  '기술': 1,
#  '기숙사': 1,
#  '기분': 1,
#  '기대': 1,
#  '대졸자': 1,
#  '대학생': 1,
#  '덕분': 1,
#  '데스크톱': 1,
#  '매료': 1,
#  '만족': 1,
#  '마취': 1,
#  '마일': 1,
#  '로렌': 1,
#  '라벨들': 1,
#  '또래': 1,
#  '때만해도': 1,
#  '때론': 1,
#  '따위': 1,
#  '디자인': 1,
#  '뒤통수': 1,
#  '뒤쪽': 1,
#  '도입': 1,
#  '도움': 1,
#  '도구': 1,
#  '데이비드': 1,
#  '글씨체': 1,
#  '극단적': 1,
#  '그러길': 1,
#  '경우': 1,
#  '결합': 1,
#  '결과물': 1,
#  '건강': 1,
#  '거절': 1,
#  '거울': 1,
#  '거부': 1,
#  '거기': 1,
#  '개정판': 1,
#  '개월정도만': 1,
#  '개발': 1,
#  '감정': 1,
#  '각종': 1,
#  '각고': 1,
#  '가치': 1,
#  '가족들': 1,
#  '가위': 1,
#  '가뿐': 1,
#  '경영자': 1,
#  '경험': 1,
#  '그동안': 1,
#  '계주': 1,
#  '그녀': 1,
#  '그날': 1,
#  '그곳': 1,
#  '구현': 1,
#  '구절': 1,
#  '교육': 1,
#  '굉장': 1,
#  '관심': 1,
#  '관계': 1,
#  '과학적': 1,
#  '과목': 1,
#  '공부': 1,
#  '공공': 1,
#  '공개적': 1,
#  '곳곳': 1,
#  '고용': 1,
#  '고등학교': 1,
#  '매진': 1,
#  '먼로': 1,
#  '약속': 1,
#  '성년기': 1,
#  '순간점': 1,
#  '순간들': 1,
#  '소음': 1,
#  '센트씩하': 1,
#  '세리프체': 1,
#  '세리프': 1,
#  '세대': 1,
#  '성장': 1,
#  '성공적': 1,
#  '명단': 1,
#  '성공': 1,
#  '선택과목': 1,
#  '선택': 1,
#  '서체수업': 1,
#  '서체들이': 1,
#  '서랍': 1,
#  '상태': 1,
#  '상실': 1,
#  '스스로': 1,
#  '스컬리': 1,
#  '스탠포드': 1,
#  '스튜디오': 1,
#  '약간': 1,
#  '아이들': 1,
#  '아무것': 1,
#  '십년': 1,
#  '실현': 1,
#  '실패한': 1,
#  '실패작': 1,
#  '실패': 1,
#  '실망': 1,
#  '실리콘': 1,
#  '신조': 1,
#  '신변정리': 1,
#  '시적': 1,
#  '시내': 1,
#  '시골길': 1,
#  '시간': 1,
#  '습작법': 1,
#  '사진': 1,
#  '사인하기': 1,
#  '사이': 1,
#  '반납': 1,
#  '바늘': 1,
#  '바깥': 1,
#  '미혼모': 1,
#  '미묘함': 1,
#  '미국': 1,
#  '뭔지': 1,
#  '물론': 1,
#  '문자': 1,
#  '문고판': 1,
#  '무너지기시작했습니다': 1,
#  '목적지': 1,
#  '목소리': 1,
#  '목구멍': 1,
#  '모험': 1,
#  '모두': 1,
#  '명확': 1,
#  '명문대': 1,
#  '바톤': 1,
#  '발행': 1,
#  '사원': 1,
#  '방바닥': 1,
#  '사실': 1,
#  '사내아이': 1,
#  '사과': 1,
#  '빈병': 1,
#  '비전': 1,
#  '브랜드': 1,
#  '부흥기': 1,
#  '부수적': 1,
#  '부분': 1,
#  '부담감': 1,
#  '복수서체': 1,
#  '복사': 1,
#  '변환점': 1,
#  '변호사': 1,
#  '벽돌': 1,
#  '백억달러': 1,
#  '배짱': 1,
#  '히치하이킹': 1}

# %%
from wordcloud import WordCloud
font = 'NanumGothic'

# %%
wc = WordCloud(random_state=1234,   #난수 고정
               font_path=font,
               width=400,
               height=400,
               background_color='white'
               )

# %%
img_wordcloud = wc.generate_from_frequencies(dic_word)

plt.figure(figsize=(10,10))
plt.axis('off')
plt.imshow(img_wordcloud)
