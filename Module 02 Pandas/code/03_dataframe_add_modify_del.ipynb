# %% [markdown]
# # DataFrame 예제 코드 - 추가, 수정, 삭제

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'name':     ['Celine','James','Jason','Hans'],
    'nation':   ['France','UK','USA','Germany'],
    'english':  [90,80,80,60],
    'math':     [100,40,40,50],
    'science':  [100,30,60,90]
})
df.index = ['a','b','c','d']
df
# Out:
#      name   nation  english  math  science
# a  Celine   France       90   100      100
# b   James       UK       80    40       30
# c   Jason      USA       80    40       60
# d    Hans  Germany       60    50       90

# %% [markdown]
# ## 추가

# %% [markdown]
# ### 컬럼 추가

# %%
df['korean'] = 80
df
# Out:
#      name   nation  english  math  science  korean
# a  Celine   France       90   100      100      80
# b   James       UK       80    40       30      80
# c   Jason      USA       80    40       60      80
# d    Hans  Germany       60    50       90      80

# %%
df['physics'] = [100,80,60,70]
df
# Out:
#      name   nation  english  math  science  korean  physics
# a  Celine   France       90   100      100      80      100
# b   James       UK       80    40       30      80       80
# c   Jason      USA       80    40       60      80       60
# d    Hans  Germany       60    50       90      80       70

# %% [markdown]
# ### 행(row) 추가

# %%
df.loc['e'] = 5
df
# Out:
#      name   nation  english  math  science  korean  physics
# a  Celine   France       90   100      100      80      100
# b   James       UK       80    40       30      80       80
# c   Jason      USA       80    40       60      80       60
# d    Hans  Germany       60    50       90      80       70
# e       5        5        5     5        5       5        5

# %%
df.loc['e'] = ['Vesper','USA',100,80,100,90,90]
df
# Out:
#      name   nation  english  math  science  korean  physics
# a  Celine   France       90   100      100      80      100
# b   James       UK       80    40       30      80       80
# c   Jason      USA       80    40       60      80       60
# d    Hans  Germany       60    50       90      80       70
# e  Vesper      USA      100    80      100      90       90

# %% [markdown]
# ## 자르기

# %%
# 행(row) 자르기
df_j = df.truncate(before='b',after='c', axis=0)
df_j
# Out:
#     name nation  english  math  science  korean  physics
# b  James     UK       80    40       30      80       80
# c  Jason    USA       80    40       60      80       60

# %% [markdown]
# ## Cell 값 수정

# %%
print(df.loc['b','nation'])
df.loc['b', 'nation'] = 'USA'
df
# Out:
# UK
#      name   nation  english  math  science  korean  physics
# a  Celine   France       90   100      100      80      100
# b   James      USA       80    40       30      80       80
# c   Jason      USA       80    40       60      80       60
# d    Hans  Germany       60    50       90      80       70
# e  Vesper      USA      100    80      100      90       90

# %%
df['nation']['b'] = 'Germany'
df
# Out:
# C:\Users\gik_k\AppData\Local\Temp\ipykernel_11620\592509137.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['nation']['b'] = 'Germany'
# C:\Users\gik_k\AppData\Local\Temp\ipykernel_11620\592509137.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nation']['b'] = 'Germany'
#      name   nation  english  math  science  korean  physics
# a  Celine   France       90   100      100      80      100
# b   James  Germany       80    40       30      80       80
# c   Jason      USA       80    40       60      80       60
# d    Hans  Germany       60    50       90      80       70
# e  Vesper      USA      100    80      100      90       90

# %%
df.loc[['a','b'], 'physics'] = [90,90]
df
# Out:
#      name   nation  english  math  science  korean  physics
# a  Celine   France       90   100      100      80       90
# b   James  Germany       80    40       30      80       90
# c   Jason      USA       80    40       60      80       60
# d    Hans  Germany       60    50       90      80       70
# e  Vesper      USA      100    80      100      90       90

# %% [markdown]
# ### replace() 메소드

# %%
df_replaced = df.replace(to_replace='USA', value='America')
df_replaced
# Out:
#      name   nation  english  math  science  korean  physics
# a  Celine   France       90   100      100      80       90
# b   James  Germany       80    40       30      80       90
# c   Jason  America       80    40       60      80       60
# d    Hans  Germany       60    50       90      80       70
# e  Vesper  America      100    80      100      90       90

# %% [markdown]
# ## row/column 위치 변경(Pivoting)

# %%
# 전치 행렬 
df2 = df.transpose()
df2
# Out:
#               a        b      c        d       e
# name     Celine    James  Jason     Hans  Vesper
# nation   France  Germany    USA  Germany     USA
# english      90       80     80       60     100
# math        100       40     40       50      80
# science     100       30     60       90     100
# korean       80       80     80       80      90
# physics      90       90     60       70      90

# %% [markdown]
# ## 삭제

# %% [markdown]
# ### 행 삭제

# %%
# drop() 메소드의 axis 파리미터로 0을 주면 row 삭제
df2 = df.drop('d', axis=0)
df2
# Out:
#      name   nation  english  math  science  korean  physics
# a  Celine   France       90   100      100      80       90
# b   James  Germany       80    40       30      80       90
# c   Jason      USA       80    40       60      80       60
# e  Vesper      USA      100    80      100      90       90

# %%
# 첫 번째 파라미터로 list를 전달하면 여러 목록을 삭제
df2.drop(['c','e'], axis=0, inplace=True)
df2
# Out:
#      name   nation  english  math  science  korean  physics
# a  Celine   France       90   100      100      80       90
# b   James  Germany       80    40       30      80       90

# %%
# index 속성으로 슬라이싱 사용
df2.drop(df2.index[0:1], inplace=True)
df2
# Out:
#     name   nation  english  math  science  korean  physics
# b  James  Germany       80    40       30      80       90

# %% [markdown]
# #### 열(column) 삭제

# %%
# drop() 메소드의 axis 파리미터로 1을 주면 column 삭제
df2 = df.drop('physics', axis=1)
df2
# Out:
#      name   nation  english  math  science  korean
# a  Celine   France       90   100      100      80
# b   James  Germany       80    40       30      80
# c   Jason      USA       80    40       60      80
# d    Hans  Germany       60    50       90      80
# e  Vesper      USA      100    80      100      90

# %%
# 첫 번째 파라미터로 list를 전달하면 여러 목록을 삭제
df2.drop(['science','korean'], axis=1, inplace=True)
df2
# Out:
#      name   nation  english  math
# a  Celine   France       90   100
# b   James  Germany       80    40
# c   Jason      USA       80    40
# d    Hans  Germany       60    50
# e  Vesper      USA      100    80

# %%
# columns 속성을 사용하여 슬라이싱
df2.drop(df2.columns[2:3], axis=1, inplace=True)
df2
# Out:
#      name   nation  math
# a  Celine   France   100
# b   James  Germany    40
# c   Jason      USA    40
# d    Hans  Germany    50
# e  Vesper      USA    80

# %% [markdown]
# ### del 문 사용

# %%
# del문을 사용하여 컬럼 삭제
del df2['math']
df2
# Out:
#      name   nation
# a  Celine   France
# b   James  Germany
# c   Jason      USA
# d    Hans  Germany
# e  Vesper      USA

# %% [markdown]
# ### 열 꺼내기 - pop() 메소드

# %%
nation = df2.pop('nation')
nation
# Out:
# a     France
# b    Germany
# c        USA
# d    Germany
# e        USA
# Name: nation, dtype: object

# %% [markdown]
# ## 복사

# %% [markdown]
# ### DataFrame 복사 - copy() 메소드

# %%
# shallow copy
df_copy = df
df_copy
# Out:
#      name   nation  english  math  science  korean  physics
# a  Celine   France       90   100      100      80       90
# b   James  Germany       80    40       30      80       90
# c   Jason      USA       80    40       60      80       60
# d    Hans  Germany       60    50       90      80       70
# e  Vesper      USA      100    80      100      90       90

# %%
# 원본 값이 변경되면 복사본의 값도 변경됨
df['nation']['b'] = 'Korea'
# Out:
# C:\Users\gik_k\AppData\Local\Temp\ipykernel_11620\403592486.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['nation']['b'] = 'Korea'
# C:\Users\gik_k\AppData\Local\Temp\ipykernel_11620\403592486.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nation']['b'] = 'Korea'

# %%
df_copy
# Out:
#      name   nation  english  math  science  korean  physics
# a  Celine   France       90   100      100      80       90
# b   James    Korea       80    40       30      80       90
# c   Jason      USA       80    40       60      80       60
# d    Hans  Germany       60    50       90      80       70
# e  Vesper      USA      100    80      100      90       90

# %%
# 복사
df_copy = df.copy(deep=True)

# %%
df['nation']['b'] = 'Germany'
df_copy['nation']['b']
# Out:
# C:\Users\gik_k\AppData\Local\Temp\ipykernel_11620\1804912502.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['nation']['b'] = 'Germany'
# C:\Users\gik_k\AppData\Local\Temp\ipykernel_11620\1804912502.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nation']['b'] = 'Germany'
# 'Korea'

# %% [markdown]
# ## 중복행 제거

# %%
df.loc[:][['name','nation','english','math','science']]
df_2 = df.copy()
df_duf = pd.concat([df, df_2])
df_duf
# Out:
#      name   nation  english  math  science
# a  Celine   France       90   100      100
# b   James  Germany       80    40       30
# c   Jason      USA       80    40       60
# d    Hans  Germany       60    50       90
# a  Celine   France       90   100      100
# b   James  Germany       80    40       30
# c   Jason      USA       80    40       60
# d    Hans  Germany       60    50       90

# %%
df_duf.drop_duplicates(inplace=True)
df_duf
# Out:
#      name   nation  english  math  science
# a  Celine   France       90   100      100
# b   James  Germany       80    40       30
# c   Jason      USA       80    40       60
# d    Hans  Germany       60    50       90

# %% [markdown]
# ## 피봇 변환

# %%
df.pivot(index='nation', columns='name', values='english')
# Out:
# name     Celine  Hans  James  Jason
# nation
# France     90.0   NaN    NaN    NaN
# Germany     NaN  60.0   80.0    NaN
# USA         NaN   NaN    NaN   80.0

# %%
df.pivot_table(index='name', values=['english','math'],aggfunc='sum')
# Out:
#         english  math
# name
# Celine       90   100
# Hans         60    50
# James        80    40
# Jason        80    40
